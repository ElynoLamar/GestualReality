# %%
import os
os.sys.path
# Out:
# ['C:\\Users\\EX119032\\3KTech\\workspaces\\Tutorials\\ImageRecon\\RealTimeObjectDetection-main',
#  'C:\\Program Files\\Python311\\python311.zip',
#  'C:\\Program Files\\Python311\\Lib',
#  'C:\\Program Files\\Python311\\DLLs',
#  '',
#  'C:\\Users\\EX119032\\AppData\\Roaming\\Python\\Python311\\site-packages',
#  'C:\\Users\\EX119032\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32',
#  'C:\\Users\\EX119032\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib',
#  'C:\\Users\\EX119032\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin',
#  'C:\\Program Files\\Python311',
#  'C:\\Program Files\\Python311\\Lib\\site-packages']

# %%
import time
import uuid
import cv2

# %%
IMAGE_PATH = 'Tensorflow/workspace/images/collectedimages'

# %%
labels = ['num1','num2','num3','num4','num5']
number_imgs =10

# %%
for label in labels:
        # !mkdir {'Tensorflow\workspace\images\collectedimages\\'+label}
        cap = cv2.VideoCapture(0)
        print('Collecting images for {}'.format(label))
        time.sleep(5)
        for imgnum in range(number_imgs):
            ret, frame = cap.read()
            imagename = os.path.join(IMAGE_PATH, label, label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
            cv2.imwrite(imagename, frame)
            cv2.imshow('frame', frame)
            time.sleep(2)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        cap.release()
# Out:
# A subdirectory or file Tensorflow\workspace\images\collectedimages\num1 already exists.
# Collecting images for num1
# Collecting images for num2
# Collecting images for num3
# Collecting images for num4
# Collecting images for num5
